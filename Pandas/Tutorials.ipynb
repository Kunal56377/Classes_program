# %%
# !pip install pandas
import matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[33], line 2
#       1 get_ipython().system('pip install pandas')
# ----> 2 import matplotlib
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# !pip install matplotlib
# Out:
# ...
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/2e/51/c77a14869b7eb9d6fb440e811b754fc3950d6868c38ace57d0632b674415/matplotlib-3.8.2-cp312-cp312-win_amd64.whl.metadata
#   Using cached matplotlib-3.8.2-cp312-cp312-win_amd64.whl.metadata (5.9 kB)
# ...
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/8e/ae/a6353db548bff1a592b85ae6bb80275f0a51dc25a0410d059e5b33183e36/contourpy-1.2.0-cp312-cp312-win_amd64.whl.metadata
#   Using cached contourpy-1.2.0-cp312-cp312-win_amd64.whl.metadata (5.8 kB)
# ...
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
# Using cached matplotlib-3.8.2-cp312-cp312-win_amd64.whl (7.6 MB)
# Using cached contourpy-1.2.0-cp312-cp312-win_amd64.whl (187 kB)
# ...

# %%
import pandas as pd
# Out:
# C:\Users\kmuga\AppData\Local\Temp\ipykernel_14752\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("Book1.csv")

# %%
df.head(10)
# Out:
#    movie_id                                        title   industry  \
# 0       101                             K.G.F: Chapter 2  Bollywood
# 1       102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2       103                        Thor: The Dark World   Hollywood
# 3       104                              Thor: Ragnarok   Hollywood
# 4       105                      Thor: Love and Thunder   Hollywood
# 5       106                                       Sholay  Bollywood
# 6       107                  Dilwale Dulhania Le Jayenge  Bollywood
# 7       108                                     3 Idiots  Bollywood
# 8       109                     Kabhi Khushi Kabhie Gham  Bollywood
# 9       110                             Bajirao Mastani   Bollywood
#
#    release_year  imdb_rating              studio  language_id
# 0          2022          8.4       Hombale Films            3
# 1          2022          7.0      Marvel Studios            5
# ...

# %%
df.tail(10)
# Out:
#     movie_id                                title   industry  release_year  \
# 29       131                                Sanju  Bollywood          2018
# 30       132            Pushpa: The Rise - Part 1  Bollywood          2021
# 31       133                                  RRR  Bollywood          2022
# 32       134             Baahubali: The Beginning  Bollywood          2015
# 33       135                    The Kashmir Files  Bollywood          2022
# 34       136                    Bajrangi Bhaijaan  Bollywood          2015
# 35       137   Captain America: The First Avenger  Hollywood          2011
# 36       138  Captain America: The Winter Soldier  Hollywood          2014
# 37       139                               Race 3  Bollywood          2018
# 38       140                            Shershaah  Bollywood          2021
#
#     imdb_rating               studio  language_id
# 29          NaN   Vinod Chopra Films            1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   movie_id      39 non-null     int64
#  1   title         39 non-null     object
#  2   industry      39 non-null     object
#  3   release_year  39 non-null     int64
#  4   imdb_rating   38 non-null     float64
#  5   studio        36 non-null     object
#  6   language_id   39 non-null     int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 2.3+ KB

# %%
df.describe()
# Out:
#          movie_id  release_year  imdb_rating  language_id
# count   39.000000     39.000000    38.000000    39.000000
# mean   120.666667   2006.282051     7.947368     3.435897
# std     11.795033     17.945750     1.180869     1.970772
# min    101.000000   1946.000000     1.900000     1.000000
# 25%    110.500000   2000.500000     7.825000     1.000000
# 50%    121.000000   2013.000000     8.100000     5.000000
# 75%    130.500000   2018.000000     8.400000     5.000000
# max    140.000000   2022.000000     9.300000     7.000000

# %%
df["industry"].value_counts()
# Out:
# industry
# Hollywood    21
# Bollywood    18
# Name: count, dtype: int64

# %%
df = pd.DataFrame({'lab':['A', 'B', 'C'], 'val':[10, 30, 20]})
ax = df.plot.bar(x='lab', y='val', rot=0)

# %%
df.im

# %%
df.columns
# Out:
# Index(['movie_id', 'title', 'industry', 'release_year', 'imdb_rating',
#        'studio', 'language_id'],
#       dtype='object')

# %%
new_df = pd.DataFrame(df["industry"].value_counts()).reset_index()

# %%
new_df.index = new_df['industry']

# %%
new_df
# Out:
#             industry  count
# industry
# Hollywood  Hollywood     21
# Bollywood  Bollywood     18

# %%
new_df.plot.bar()
# Out:
# <Axes: xlabel='industry'>

# %%
df["studio"].value_counts()
# Out:
# studio
# Marvel Studios               8
# Vinod Chopra Films           3
# Salman Khan Films            2
# Universal Pictures           2
# Dharma Productions           2
# Warner Bros. Pictures        2
# Paramount Pictures           2
# Zee Studios                  1
# Arka Media Works             1
# DVV Entertainment            1
# Mythri Movie Makers          1
# Vinod Chopra Productions     1
# Government of West Bengal    1
# Hombale Films                1
# Syncopy                      1
# 20th Century Fox             1
# Universal Pictures           1
# Columbia Pictures            1
# Castle Rock Entertainment    1
# Yash Raj Films               1
# United Producers             1
# Liberty Films                1
# Name: count, dtype: int64

# %%
#Print all movies which release year is less that 1974

df[df['release_year'] < 1975]
# Out:
#     movie_id                  title   industry  release_year  imdb_rating  \
# 16       118  It's a Wonderful Life  Hollywood          1946          8.6
# 18       120          The Godfather  Hollywood          1972          9.2
# 25       127        Pather Panchali  Bollywood          1955          8.3
#
#                        studio  language_id
# 16              Liberty Films            5
# 18         Paramount Pictures            5
# 25  Government of West Bengal            7

# %%
df[df['release_year'] > 1975]
# Out:
#     movie_id                                        title   industry  \
# 0        101                             K.G.F: Chapter 2  Bollywood
# 1        102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2        103                        Thor: The Dark World   Hollywood
# 3        104                              Thor: Ragnarok   Hollywood
# 4        105                      Thor: Love and Thunder   Hollywood
# 6        107                  Dilwale Dulhania Le Jayenge  Bollywood
# 7        108                                     3 Idiots  Bollywood
# 8        109                     Kabhi Khushi Kabhie Gham  Bollywood
# 9        110                             Bajirao Mastani   Bollywood
# 10       111                     The Shawshank Redemption  Hollywood
# 11       112                                    Inception  Hollywood
# 12       113                                 Interstellar  Hollywood
# 13       115                     The Pursuit of Happyness  Hollywood
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   movie_id      39 non-null     int64
#  1   title         39 non-null     object
#  2   industry      39 non-null     object
#  3   release_year  39 non-null     int64
#  4   imdb_rating   38 non-null     float64
#  5   studio        36 non-null     object
#  6   language_id   39 non-null     int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 2.3+ KB

# %%
df[df['imdb_rating'].isna()]
# Out:
#     movie_id  title   industry  release_year  imdb_rating              studio  \
# 29       131  Sanju  Bollywood          2018          NaN  Vinod Chopra Films
#
#     language_id
# 29            1

# %%
df[df['studio'].isna()]
# Out:
#     movie_id             title   industry  release_year  imdb_rating studio  \
# 9        110  Bajirao Mastani   Bollywood          2015          7.2    NaN
# 22       124          Parasite  Hollywood          2019          8.5    NaN
# 26       128  Taare Zameen Par  Bollywood          2007          8.3    NaN
#
#     language_id
# 9             1
# 22            5
# 26            1

# %%
df.fillna("missing",inplace=True)
# Out:
# C:\Users\kmuga\AppData\Local\Temp\ipykernel_14752\1256532227.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'missing' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna("missing",inplace=True)

# %%
df[df['imdb_rating'] == "missing"]
# Out:
#     movie_id  title   industry  release_year imdb_rating              studio  \
# 29       131  Sanju  Bollywood          2018     missing  Vinod Chopra Films
#
#     language_id
# 29            1

# %%
df[df['studio'] == "missing"]
# Out:
#     movie_id             title   industry  release_year imdb_rating   studio  \
# 9        110  Bajirao Mastani   Bollywood          2015         7.2  missing
# 22       124          Parasite  Hollywood          2019         8.5  missing
# 26       128  Taare Zameen Par  Bollywood          2007         8.3  missing
#
#     language_id
# 9             1
# 22            5
# 26            1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   movie_id      39 non-null     int64
#  1   title         39 non-null     object
#  2   industry      39 non-null     object
#  3   release_year  39 non-null     int64
#  4   imdb_rating   39 non-null     object
#  5   studio        39 non-null     object
#  6   language_id   39 non-null     int64
# dtypes: int64(3), object(4)
# memory usage: 2.3+ KB

# %%
df.columns
# Out:
# Index(['movie_id', 'title', 'industry', 'release_year', 'imdb_rating',
#        'studio', 'language_id'],
#       dtype='object')

# %%
df1 = df.dropna()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35 entries, 0 to 38
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   movie_id      35 non-null     int64
#  1   title         35 non-null     object
#  2   industry      35 non-null     object
#  3   release_year  35 non-null     int64
#  4   imdb_rating   35 non-null     float64
#  5   studio        35 non-null     object
#  6   language_id   35 non-null     int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 2.2+ KB
